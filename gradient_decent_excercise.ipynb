# %%
import pandas as pd
from sklearn import linear_model
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
def gradient_decent(x,y):
    m = 0
    b = 0
    n = len(x)
    learing_rate = 0.0002
    iterations = 1000
    plt.scatter(x, y, color='red', marker='+')
    for i in range(iterations):
        y_predicted = m*x+b
        plt.plot(x, y_predicted, color='green')
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m = m-learing_rate*md
        b = b-learing_rate*bd

    print("m {} b {} learning_rate {}".format(m, b, learing_rate))

# %%
df = pd.read_csv("./resource/test_scores.csv")
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
x = np.array(df['math'])
y = np.array(df['cs'])

# %%
gradient_decent(x,y)
# Out:
# m -1.1603673477577725e+265 b -1.6373780861079202e+263 learning_rate 0.0003

# %%
model_reg = linear_model.LinearRegression()
model_reg.fit(df[['math']], df.cs)
# Out:
# LinearRegression()

# %%
model_reg.coef_
# Out:
# array([1.01773624])

# %%
model_reg.intercept_
# Out:
# 1.9152193111569034

# %%
def gradient_decent1(x,y):
    m = b = 0
    learing_rate = 0.0002
    n = len(x) 
    iterations = 1000000
    y_predicted = m*x+b
    cost = (1/n)*sum([val**2 for val in (y-y_predicted)])
    for i in range(iterations):
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m = m-learing_rate*md
        b = b-learing_rate*bd
        y_predicted = m*x+b
        new_cost = (1/n)*sum([val**2 for val in (y-y_predicted)])

        if math.isclose(cost, new_cost, rel_tol=1e-20):
            cost = new_cost
            t = i
            break
        cost = new_cost

    print("m {} b {}".format(m, b))

# %%
gradient_decent1(x,y)
# Out:
# m 1.0177381667793246 b 1.9150826134339467

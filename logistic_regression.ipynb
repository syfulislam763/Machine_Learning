# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./resource/insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age, df.bought_insurance, color='green', marker='+')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, test_size=0.1)

# %%
X_train
# Out:
#     age
# 24   50
# 1    25
# 12   27
# 4    46
# 7    60
# 23   45
# 8    62
# 18   19
# 6    55
# 21   26
# 20   21
# 3    52
# 26   23
# 25   54
# 14   49
# 19   18
# 9    61
# 15   55
# 5    56
# 16   25
# 17   58
# 13   29
# 10   18
# 2    47

# %%
y_train
# Out:
# 24    1
# 1     0
# 12    0
# 4     1
# 7     1
# 23    1
# 8     1
# 18    0
# 6     0
# 21    0
# 20    0
# 3     0
# 26    0
# 25    1
# 14    1
# 19    0
# 9     1
# 15    1
# 5     1
# 16    1
# 17    1
# 13    0
# 10    0
# 2     1
# Name: bought_insurance, dtype: int64

# %%
X_test
# Out:
#     age
# 11   28
# 22   40
# 0    22

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(df[['age']], df.bought_insurance)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 1, 0])

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
model.predict([[67]])
# Out:
# /home/javedjarif/Desktop/workdir/ML/env/lib64/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
model.coef_
# Out:
# array([[0.13546543]])

# %%
model.intercept_
# Out:
# array([-5.26279121])
